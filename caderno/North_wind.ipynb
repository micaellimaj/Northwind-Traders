# %% [markdown]
# # Projeto: Análise de dados da Northwind![ico-nortwind.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Introdução

# %% [markdown]
# A Northwind Traders é uma loja fictícia que gerencia pedidos, produtos, clientes, fornecedores e muitos outros aspectos de uma pequena empresa. Hoje a empresa possui cerca de 30 funcionários e um faturamento mensal de 1 milhão e meio de reais. Seus clientes e fornecedores estão distribuídos em diversos países. Seus principais produtos hoje são alimentos, bebidas e utilidades domésticas.
#
# Apesar de seu sucesso inicial, a Northwind Traders enfrenta desafios significativos devido ao crescimento acelerado. A gestão de dados, que antes era realizada de forma manual e sob demanda em planilhas, tornou-se inadequada. Esse método, eficaz quando a empresa era menor, agora resulta em inconsistências de dados entre diferentes áreas, gerando conflitos e ineficiências durante as reuniões de tomada de decisão.
#
# Para enfrentar esses desafios, a Northwind Traders busca implementar uma abordagem mais robusta de gerenciamento e análise de dados. A empresa visa aprimorar a compreensão de seus dados para atingir dois objetivos estratégicos de médio prazo: aumentar o ticket médio e reduzir o churn. Com uma melhor gestão dos dados, a Northwind Traders espera tomar decisões mais informadas, alinhando suas operações e estratégias de maneira a sustentar e impulsionar seu crescimento contínuo no mercado global.

# %% [markdown]
# **Objetivo:**
#
# Com esse projeto utilizando uma base de dados da empresa  fictícia Nortwind Traders passamos por diversas etapas importante na análise de dados, como o pré-processamento, em que os dados são explorados e analisados para garantir que estarão em bom estado para a próxima etapa que seria a visualização de dados utilizando power bi para fazer conexões entre os diferentes datasets e gerar visualizações e com sigo insights para os tomadores de decisão.

# %% [markdown]
# ## Pré-Processamento

# %% [markdown]
# Bibliotecas que serão utilizadas:

# %%
import pandas as pd

# %%
from google.colab import drive

# %% [markdown]
# Caminho da fonte de dados do meu drive:

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * **DATASET: Categories.csv (Categorias de produtos)**

# %% [markdown]
# **Atributos**:
#
# 1. category_id: Refere-se ao identificador único para cada categoria de produtos. É usado para diferenciar e identificar unicamente cada categoria no sistema.
#
# 2. category_name: Nome da categoria de produtos. Isso ajuda a descrever de forma geral o tipo de produtos que estão agrupados sob essa categoria, como bebidas, condimentos, confeitos, etc.
#
# 3. description: Descrição detalhada dos produtos que pertencem a cada categoria. Fornece informações específicas sobre os tipos de itens incluídos na categoria, como bebidas suaves, cafés, chás, doces, pães, etc.
#
# 4. picture: Representação da imagem associada a cada categoria. Pode ser um caminho para um arquivo de imagem ou dados de imagem codificados. Isso ajuda na identificação visual e apresentação dos produtos.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/categories.csv'
categories = pd.read_csv(path, sep=';')

# %%
categories.head(10)
# Out:
#    category_id   category_name  \
# 0            1       Beverages
# 1            2      Condiments
# 2            3     Confections
# 3            4  Dairy Products
# 4            5  Grains/Cereals
# 5            6    Meat/Poultry
# 6            7         Produce
# 7            8         Seafood
#
#                                          description picture
# 0        Soft drinks, coffees, teas, beers, and ales      \x
# 1  Sweet and savory sauces, relishes, spreads, an...      \x
# 2                Desserts, candies, and sweet breads      \x
# 3                                            Cheeses      \x
# 4                Breads, crackers, pasta, and cereal      \x
# 5                                     Prepared meats      \x
# 6                          Dried fruit and bean curd      \x
# 7                                   Seaweed and fish      \x

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   category_id    8 non-null      int64
#  1   category_name  8 non-null      object
#  2   description    8 non-null      object
#  3   picture        8 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 384.0+ bytes

# %%
valores_nulos = categories.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Vimos que os dados estão limpos e não é necessário nenhum tipo de pré-processamento.

# %% [markdown]
# * **DATASET: Customer_customer_demo (Classificação do cliente)**

# %% [markdown]
# **Atributos**:
#
# 1. customer_id: Refere-se ao identificador único de cada cliente. É usado para diferenciar e identificar unicamente cada cliente no sistema.
#
# 2. customer_type_id: Refere-se ao identificador único que classifica o tipo de cliente. Embora os valores estejam ausentes, normalmente seria usado para categorizar clientes com base em critérios como pessoa física ou jurídica, tipo de assinatura, nível de serviço, entre outros.

# %%
path = '/content/drive/MyDrive/northwind/customer_customer_demo.csv'
customer_demo = pd.read_csv(path, sep=';')

# %%
customer_demo.head()
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_type_id]
# Index: []

# %% [markdown]
# > Como vemos os dados estão vazios, então acabei escolhendo não utilizar esse dataset para a análise de dados no power BI mais na frente.

# %% [markdown]
# * **DATASET: Customer_demographics (demografia dos clientes)**

# %% [markdown]
# **Atributos**:
#
# 1. customer_type_id: Refere-se ao identificador único que classifica o tipo de cliente. É usado para diferenciar e identificar unicamente cada tipo de cliente no sistema.
#
# 2. customer_desc: Descrição do tipo de cliente. Geralmente fornece uma explicação ou um nome que descreve o tipo de cliente, como "pessoa física", "pessoa jurídica", "cliente premium", "cliente regular", entre outros.

# %%
path = '/content/drive/MyDrive/northwind/customer_demographics.csv'  # Ensure the file extension is correct
customer_demographics = pd.read_csv(path, sep=';')

# %%
customer_demographics.head()
# Out:
# Empty DataFrame
# Columns: [customer_type_id, customer_desc]
# Index: []

# %% [markdown]
# > Como vemos os dados estão vazios, então acabei escolhendo não utilizar esse dataset para a análise de dados no power BI mais na frente.

# %% [markdown]
# * **DATASET: Customers (Clientes)**

# %% [markdown]
# **Atributos**:
#
# 1. customer_id: Refere-se ao identificador único de cada cliente. É usado para diferenciar e identificar unicamente cada cliente no sistema.
#
# 2. company_name: Nome da empresa do cliente. Ajuda a identificar a organização associada ao cliente.
#
# 3. contact_name: Nome da pessoa de contato na empresa do cliente. Facilita a comunicação direta com o representante ou responsável.
#
# 4. contact_title: Título do cargo da pessoa de contato na empresa do cliente. Indica a posição e a responsabilidade da pessoa dentro da empresa.
#
# 5. address: Endereço da empresa do cliente. Inclui a localização física onde a empresa está situada.
#
# 6. city: Cidade onde a empresa do cliente está localizada. Faz parte das informações de endereço para ajudar na identificação geográfica.
#
# 7. region: Região ou estado onde a empresa do cliente está localizada. Complementa as informações de endereço para uma localização mais precisa.
#
# 8. postal_code: Código postal da área onde a empresa do cliente está localizada. Auxilia na entrega de correspondências e encomendas.
#
# 9. country: País onde a empresa do cliente está localizada. Ajuda na identificação internacional da localização da empresa.
#
# 10. phone: Número de telefone da empresa do cliente. É usado para comunicações telefônicas diretas com a empresa.
#
# 11. fax: Número de fax da empresa do cliente. É utilizado para enviar e receber documentos via fax.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/customers.csv'
customers = pd.read_csv(path, sep=';')

# %%
customers.head(10)
# Out:
#   customer_id                        company_name        contact_name  \
# 0       ALFKI                 Alfreds Futterkiste        Maria Anders
# 1       ANATR  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2       ANTON             Antonio Moreno Taquería      Antonio Moreno
# 3       AROUT                     Around the Horn        Thomas Hardy
# 4       BERGS                  Berglunds snabbköp  Christina Berglund
# 5       BLAUS             Blauer See Delikatessen          Hanna Moos
# 6       BLONP            Blondesddsl père et fils  Frédérique Citeaux
# 7       BOLID           Bólido Comidas preparadas       Martín Sommer
# 8       BONAP                            Bon app'    Laurence Lebihan
# 9       BOTTM               Bottom-Dollar Markets   Elizabeth Lincoln
#
#           contact_title                        address         city region  \
# 0  Sales Representative                  Obere Str. 57       Berlin    NaN
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    91 non-null     object
#  1   company_name   91 non-null     object
#  2   contact_name   91 non-null     object
#  3   contact_title  91 non-null     object
#  4   address        91 non-null     object
#  5   city           91 non-null     object
#  6   region         31 non-null     object
#  7   postal_code    90 non-null     object
#  8   country        91 non-null     object
#  9   phone          91 non-null     object
#  10  fax            69 non-null     object
# dtypes: object(11)
# memory usage: 7.9+ KB

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = customers.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Há valores nulos na tabela.

# %%
valores_nulos = customers.isnull().sum()
print(valores_nulos)
# Out:
# customer_id       0
# company_name      0
# contact_name      0
# contact_title     0
# address           0
# city              0
# region           60
# postal_code       1
# country           0
# phone             0
# fax              22
# dtype: int64

# %% [markdown]
# **Tratando valores nulos da coluna "region":**

# %%
cidades_com_nulos = customers[customers['region'].isnull()]['city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {cidades_com_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['Berlin', 'México D.F.', 'London', 'Luleå', 'Mannheim', 'Strasbourg', 'Madrid', 'Marseille', 'Buenos Aires', 'Bern', 'Aachen', 'Nantes', 'Graz', 'Lille', 'Bräcke', 'München', 'Torino', 'Lisboa', 'Barcelona', 'Sevilla', 'Brandenburg', 'Versailles', 'Toulouse', 'Frankfurt a.M.', 'Bergamo', 'Bruxelles', 'Leipzig', 'Köln', 'Paris', 'Salzburg', 'Cunewalde', 'Reggio Emilia', 'Genève', 'Stavern', 'Kobenhavn', 'Charleroi', 'Münster', 'Århus', 'Lyon', 'Reims', 'Stuttgart', 'Oulu', 'Helsinki', 'Warszawa']

# %% [markdown]
# > Cidades que possuem regiões em nulo.

# %%
cidades = [
    'Berlin', 'México D.F.', 'London', 'Luleå', 'Mannheim', 'Strasbourg', 'Madrid',
    'Marseille', 'Buenos Aires', 'Bern', 'Aachen', 'Nantes', 'Graz', 'Lille',
    'Bräcke', 'München', 'Torino', 'Lisboa', 'Barcelona', 'Sevilla', 'Brandenburg',
    'Versailles', 'Toulouse', 'Frankfurt a.M.', 'Bergamo', 'Bruxelles', 'Leipzig',
    'Köln', 'Paris', 'Salzburg', 'Cunewalde', 'Reggio Emilia', 'Genève', 'Stavern',
    'Kobenhavn', 'Charleroi', 'Münster', 'Århus', 'Lyon', 'Reims', 'Stuttgart',
    'Oulu', 'Helsinki', 'Warszawa'
]
regioes = [
    'BE', 'DF', 'LDN', 'LU', 'MH', 'ST', 'MD', 'MS', 'BA', 'BR', 'AC', 'NA', 'GR', 'LL',
    'BK', 'MU', 'TO', 'LB', 'BC', 'SV', 'BRB', 'VS', 'TL', 'FF', 'BG', 'BX', 'LP',
    'KO', 'PA', 'SZ', 'CU', 'RE', 'GE', 'ST', 'CO', 'CH', 'MS', 'AR', 'LY', 'RM', 'ST',
    'OU', 'HE', 'WA'
]

# %%
cidade_para_regiao = dict(zip(cidades, regioes))


customers['region'] = customers.apply(lambda row: cidade_para_regiao[row['city']] if pd.isnull(row['region']) else row['region'], axis=1)

# %% [markdown]
# > Substituindo os valores nulos da coluna "region" pelos valores da variável regioes com base na coluna "city".

# %% [markdown]
# **Tratando valores nulos da coluna "postal code":**

# %%
postal_com_nulos = customers[customers['postal_code'].isnull()]['city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {postal_com_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['Cork']

# %%
cork_data = customers[customers['city'] == 'Cork']

# %%
cork_data.head()
# Out:
#    customer_id                  company_name      contact_name  \
# 36       HUNGO  Hungry Owl All-Night Grocers  Patricia McKenna
#
#       contact_title           address  city    region postal_code  country  \
# 36  Sales Associate  8 Johnstown Road  Cork  Co. Cork         NaN  Ireland
#
#        phone        fax
# 36  2967 542  2967 3333

# %% [markdown]
# > Cidade que possui "postal code" como nulo.

# %%
customers.loc[(customers['city'] == 'Cork') & (customers['postal_code'].isnull()), 'postal_code'] = 'T12 X672'

# %% [markdown]
# > Substituindo postal code nulo por "T12 X672", que é o verdadeiro valor da cidade , retirado de uma pesquisa na internet.

# %% [markdown]
# **Tratando valores nulos da coluna "fax":**

# %%
customers['fax'] = customers['fax'].fillna('desconhecido')

# %% [markdown]
# > os valores faltantes da coluna fax foram substituidos pela string "desconhecido".

# %% [markdown]
# Verificando valores nulos novamente:

# %%
valores_nulos = customers.isnull().sum()
print(valores_nulos)
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %% [markdown]
# Como vimos os valores estão no formato correto para as análises, então abaixo foi salvo o dataset atualizado em outro arquivo csv.

# %%
customers.to_csv('./customers.csv',sep=',',index=False)

# %% [markdown]
# * **DATASET: employee_territories (Território dos empregados)**

# %% [markdown]
# **Atributos**:
#
# 1. employee_id: Refere-se ao identificador único de cada empregado. É usado para diferenciar e identificar unicamente cada empregado no sistema.
#
# 2. territory_id: Refere-se ao identificador único de cada território. É usado para associar empregados aos territórios específicos que eles gerenciam ou nos quais trabalham.

# %%
path = '/content/drive/MyDrive/northwind/employee_territories.csv'  # Ensure the file extension is correct
employee_territories = pd.read_csv(path, sep=';')

# %%
employee_territories.head(10)
# Out:
#    employee_id  territory_id
# 0            1          6897
# 1            1         19713
# 2            2          1581
# 3            2          1730
# 4            2          1833
# 5            2          2116
# 6            2          2139
# 7            2          2184
# 8            2         40222
# 9            3         30346

# %%
employee_territories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   employee_id   49 non-null     int64
#  1   territory_id  49 non-null     int64
# dtypes: int64(2)
# memory usage: 912.0 bytes

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = employee_territories.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %%
valores_nulos = employee_territories.isnull().sum()
print(valores_nulos)
# Out:
# employee_id     0
# territory_id    0
# dtype: int64

# %% [markdown]
# > Vemos que os dados estão limpos e não precisam de nenhum pré-processamento.

# %% [markdown]
# * **DATASET: employees (Empregados)**

# %% [markdown]
# **Atributos**:
#
# 1. employee_id: Refere-se ao identificador único de cada empregado. É usado para diferenciar e identificar unicamente cada empregado no sistema.
#
# 2. last_name: Sobrenome do empregado. Facilita a identificação e o registro formal dos empregados.
#
# 3. first_name: Nome do empregado. Usado em conjunto com o sobrenome para a identificação completa do empregado.
#
# 4. title: Cargo do empregado na empresa. Descreve a função e a posição hierárquica do empregado.
#
# 5. title_of_courtesy: Título de cortesia do empregado (ex.: Sr., Sra., Dr.). Utilizado para formalidades e endereçamentos apropriados.
#
# 6. birth_date: Data de nascimento do empregado. Pode ser usado para cálculos de idade e para registros de RH.
#
# 7. hire_date: Data de contratação do empregado. Importante para determinar a antiguidade e calcular benefícios relacionados ao tempo de serviço.
#
# 8. address: Endereço residencial do empregado. Inclui a localização física onde o empregado reside.
#
# 9. city: Cidade onde o empregado reside. Parte do endereço para ajudar na identificação geográfica.
#
# 10. region: Região ou estado onde o empregado reside. Complementa as informações de endereço para uma localização mais precisa.
#
# 11. postal_code: Código postal da área onde o empregado reside. Auxilia na entrega de correspondências e encomendas.
#
# 12. country: País onde o empregado reside. Ajuda na identificação internacional da localização do empregado.
#
# 13. home_phone: Número de telefone residencial do empregado. Usado para comunicações pessoais.
#
# 14. extension: Ramal telefônico do empregado na empresa. Facilita a comunicação interna dentro da organização.
#
# 15. photo: Representação da imagem do empregado. Pode ser um caminho para um arquivo de imagem ou dados de imagem codificados.
#
# 16. notes: Notas adicionais sobre o empregado. Pode incluir informações sobre formação, histórico profissional, e outras observações relevantes.
#
# 17. reports_to: Identificador do superior imediato do empregado. Usado para delinear a estrutura hierárquica e de reporte na empresa.
#
# 18. photo_path: Caminho para o arquivo de foto do empregado. Indica a localização do arquivo de imagem no sistema ou na web.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/employees.csv'
employees = pd.read_csv(path, sep=';')

# %%
employees.head(20)
# Out:
#    employee_id  last_name first_name                     title  \
# 0            1    Davolio      Nancy      Sales Representative
# 1            2     Fuller     Andrew     Vice President, Sales
# 2            3  Leverling      Janet      Sales Representative
# 3            4    Peacock   Margaret      Sales Representative
# 4            5   Buchanan     Steven             Sales Manager
# 5            6     Suyama    Michael      Sales Representative
# 6            7       King     Robert      Sales Representative
# 7            8   Callahan      Laura  Inside Sales Coordinator
# 8            9  Dodsworth       Anne      Sales Representative
#
#   title_of_courtesy  birth_date   hire_date                         address  \
# 0               Ms.  1948-12-08  1992-05-01     507 - 20th Ave. E.\nApt. 2A
# 1               Dr.  1952-02-19  1992-08-14              908 W. Capital Way
# 2               Ms.  1963-08-30  1992-04-01              722 Moss Bay Blvd.
# ...

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        9 non-null      int64
#  1   last_name          9 non-null      object
#  2   first_name         9 non-null      object
#  3   title              9 non-null      object
#  4   title_of_courtesy  9 non-null      object
#  5   birth_date         9 non-null      datetime64[ns]
#  6   hire_date          9 non-null      datetime64[ns]
#  7   address            9 non-null      object
#  8   city               9 non-null      object
#  9   region             5 non-null      object
#  10  postal_code        9 non-null      object
#  11  country            9 non-null      object
#  12  home_phone         9 non-null      object
#  13  extension          9 non-null      int64
#  14  photo              9 non-null      object
# ...

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = employees.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Há valores nulos na tabela.

# %%
valores_nulos = employees.isnull().sum()
print(valores_nulos)
# Out:
# employee_id          0
# last_name            0
# first_name           0
# title                0
# title_of_courtesy    0
# birth_date           0
# hire_date            0
# address              0
# city                 0
# region               4
# postal_code          0
# country              0
# home_phone           0
# extension            0
# photo                0
# notes                0
# reports_to           1
# photo_path           0
# dtype: int64

# %% [markdown]
# **Tratando valores nulos da coluna "region":**

# %%
cidades_nulos = employees[employees['region'].isnull()]['city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {cidades_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['London']

# %% [markdown]
# > Cidade que possui "region" como nulo.

# %%
cidades = [
    'London'
]
regioes = [
    'LDN'
]

# %%
cidade_para_regiao = dict(zip(cidades, regioes))

employees['region'] = employees.apply(lambda row: cidade_para_regiao[row['city']] if pd.isnull(row['region']) else row['region'], axis=1)

# %% [markdown]
# > Substituindo as regiões nulas pelo valor da variável regioes com base nas cidades.

# %%
valores_nulos = employees.isnull().sum()
print(valores_nulos)
# Out:
# employee_id          0
# last_name            0
# first_name           0
# title                0
# title_of_courtesy    0
# birth_date           0
# hire_date            0
# address              0
# city                 0
# region               0
# postal_code          0
# country              0
# home_phone           0
# extension            0
# photo                0
# notes                0
# reports_to           1
# photo_path           0
# dtype: int64

# %% [markdown]
# **Tratando os valores nulos da coluna "reports_to"**

# %%
reports_to_median = employees.reports_to.median()
employees.fillna(reports_to_median, inplace = True)
employees.reports_to.isnull().sum()
# Out:
# 0

# %% [markdown]
# > Acima os valores nulos foram substituidos pela mediana da coluna.

# %%
valores_nulos = employees.isnull().sum()
print(valores_nulos)
# Out:
# employee_id          0
# last_name            0
# first_name           0
# title                0
# title_of_courtesy    0
# birth_date           0
# hire_date            0
# address              0
# city                 0
# region               0
# postal_code          0
# country              0
# home_phone           0
# extension            0
# photo                0
# notes                0
# reports_to           0
# photo_path           0
# dtype: int64

# %% [markdown]
# > Observamos que agora não temos mais valores nulos, no entando ainda temos que passar pela etapa de converter as colunas para o formato correto, apesar do power bi conseguir identificar as colunas de data facilmente, é uma boa prática realizar a conversão dos valores de data que estão em "object" para "datetime", assim podemos prevenir problemas futuros.

# %% [markdown]
# **Convertendo as colunas referente as datas: "birth_date" e "hire_date":**

# %%
employees['birth_date'] = pd.to_datetime(employees['birth_date'])

# %%
employees['hire_date'] = pd.to_datetime(employees['hire_date'])

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   employee_id        9 non-null      int64
#  1   last_name          9 non-null      object
#  2   first_name         9 non-null      object
#  3   title              9 non-null      object
#  4   title_of_courtesy  9 non-null      object
#  5   birth_date         9 non-null      datetime64[ns]
#  6   hire_date          9 non-null      datetime64[ns]
#  7   address            9 non-null      object
#  8   city               9 non-null      object
#  9   region             9 non-null      object
#  10  postal_code        9 non-null      object
#  11  country            9 non-null      object
#  12  home_phone         9 non-null      object
#  13  extension          9 non-null      int64
#  14  photo              9 non-null      object
# ...

# %% [markdown]
# > Podemos observar que agora todos as colunas estão no formato correto.

# %%
employees.head()
# Out:
#    employee_id  last_name first_name                  title title_of_courtesy  \
# 0            1    Davolio      Nancy   Sales Representative               Ms.
# 1            2     Fuller     Andrew  Vice President, Sales               Dr.
# 2            3  Leverling      Janet   Sales Representative               Ms.
# 3            4    Peacock   Margaret   Sales Representative              Mrs.
# 4            5   Buchanan     Steven          Sales Manager               Mr.
#
#   birth_date  hire_date                      address      city region  \
# 0 1948-12-08 1992-05-01  507 - 20th Ave. E.\nApt. 2A   Seattle     WA
# 1 1952-02-19 1992-08-14           908 W. Capital Way    Tacoma     WA
# 2 1963-08-30 1992-04-01           722 Moss Bay Blvd.  Kirkland     WA
# 3 1937-09-19 1993-05-03         4110 Old Redmond Rd.   Redmond     WA
# 4 1955-03-04 1993-10-17              14 Garrett Hill    London    LDN
#
#   postal_code country      home_phone  extension photo  \
# ...

# %% [markdown]
# Salvando o arquivo após o processamento:

# %%
employees.to_csv('./employees.csv',sep=',',index=False)

# %% [markdown]
# **DATASET: order_details (detalhes dos pedidos)**

# %% [markdown]
# **Atributos**:
#
# 1. order_id: Refere-se ao identificador único de cada pedido. É usado para diferenciar e identificar unicamente cada pedido no sistema.
#
# 2. product_id: Refere-se ao identificador único de cada produto. É usado para associar produtos específicos aos pedidos.
#
# 3. unit_price: Preço unitário do produto no pedido. Indica o custo de uma unidade do produto.
#
# 4. quantity: Quantidade de unidades do produto incluídas no pedido. Especifica quantas unidades do produto foram compradas.
#
# 5. discount: Desconto aplicado ao produto no pedido. Representado como um valor decimal, indica a porcentagem de desconto aplicada ao preço unitário do produto.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/order_details.csv'
order_details = pd.read_csv(path, sep=';')

# %%
order_details.head(10)
# Out:
#    order_id  product_id  unit_price  quantity  discount
# 0     10248          11        14.0        12      0.00
# 1     10248          42         9.8        10      0.00
# 2     10248          72        34.8         5      0.00
# 3     10249          14        18.6         9      0.00
# 4     10249          51        42.4        40      0.00
# 5     10250          41         7.7        10      0.00
# 6     10250          51        42.4        35      0.15
# 7     10250          65        16.8        15      0.15
# 8     10251          22        16.8         6      0.05
# 9     10251          57        15.6        15      0.05

# %%
order_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    2155 non-null   int64
#  1   product_id  2155 non-null   int64
#  2   unit_price  2155 non-null   float64
#  3   quantity    2155 non-null   int64
#  4   discount    2155 non-null   float64
# dtypes: float64(2), int64(3)
# memory usage: 84.3 KB

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = order_details.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Como vimos os dados não precisam de nenhum pré-processamento.

# %% [markdown]
# * **DATASET: orders (pedidos)**

# %% [markdown]
# **Atributos**:
#
# 1. order_id: Refere-se ao identificador único de cada pedido. É usado para diferenciar e identificar unicamente cada pedido no sistema.
#
# 2. customer_id: Refere-se ao identificador único do cliente que fez o pedido. Indica qual cliente fez o pedido, permitindo a associação do pedido ao cliente correspondente.
#
# 3. employee_id: Refere-se ao identificador único do funcionário responsável pelo pedido. Indica qual funcionário da empresa processou ou gerenciou o pedido.
#
# 4. order_date: Data em que o pedido foi feito. Representa o momento em que o pedido foi registrado no sistema.
#
# 5. required_date: Data em que o pedido deve ser entregue. Indica a data limite ou esperada para a entrega do pedido ao cliente.
#
# 6. shipped_date: Data em que o pedido foi enviado. Representa o momento em que o pedido deixou o armazém ou local de origem para entrega ao cliente.
#
# 7. ship_via: Refere-se ao identificador único do método de envio escolhido para o pedido. Indica qual método de transporte foi utilizado para entregar o pedido ao cliente.
#
# 8. freight: Valor do frete associado ao envio do pedido. Representa o custo monetário do transporte do pedido ao cliente.
#
# 9. ship_name: Nome do destinatário para envio do pedido. Indica o nome da pessoa ou empresa que receberá o pedido.
#
# 10. ship_address: Endereço de entrega para o pedido. Inclui a localização física onde o pedido deve ser entregue.
#
# 11. ship_city: Cidade de entrega para o pedido. Faz parte das informações de endereço para identificar a localização geográfica da entrega.
#
# 12. ship_region: Região de entrega para o pedido. Complementa as informações de endereço para uma localização mais precisa, quando aplicável.
#
# 13. ship_postal_code: Código postal da área de entrega para o pedido. Auxilia na entrega de correspondências e encomendas.
#
# 14. ship_country: País de entrega para o pedido. Indica o país onde o pedido deve ser entregue ao cliente.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/orders.csv'
orders = pd.read_csv(path, sep=';')

# %%
orders.head()
# Out:
#    order_id customer_id  employee_id  order_date required_date shipped_date  \
# 0     10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 1     10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 2     10250       HANAR            4  1996-07-08    1996-08-05   1996-07-12
# 3     10251       VICTE            3  1996-07-08    1996-08-05   1996-07-15
# 4     10252       SUPRD            4  1996-07-09    1996-08-06   1996-07-11
#
#    ship_via  freight                  ship_name          ship_address  \
# 0         3    32.38  Vins et alcools Chevalier    59 rue de l'Abbaye
# 1         1    11.61         Toms Spezialitäten         Luisenstr. 48
# 2         2    65.83              Hanari Carnes       Rua do Paço, 67
# 3         1    41.34       Victuailles en stock    2, rue du Commerce
# 4         2    51.30           Suprêmes délices  Boulevard Tirou, 255
#
#         ship_city ship_region ship_postal_code ship_country
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          830 non-null    int64
#  1   customer_id       830 non-null    object
#  2   employee_id       830 non-null    int64
#  3   order_date        830 non-null    object
#  4   required_date     830 non-null    object
#  5   shipped_date      809 non-null    object
#  6   ship_via          830 non-null    int64
#  7   freight           830 non-null    float64
#  8   ship_name         830 non-null    object
#  9   ship_address      830 non-null    object
#  10  ship_city         830 non-null    object
#  11  ship_region       323 non-null    object
#  12  ship_postal_code  811 non-null    object
#  13  ship_country      830 non-null    object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 90.9+ KB

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = orders.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Há valores nulos na tabela.

# %%
valores_nulos = orders.isnull().sum()
print(valores_nulos)
# Out:
# order_id              0
# customer_id           0
# employee_id           0
# order_date            0
# required_date         0
# shipped_date         21
# ship_via              0
# freight               0
# ship_name             0
# ship_address          0
# ship_city             0
# ship_region         507
# ship_postal_code     19
# ship_country          0
# dtype: int64

# %% [markdown]
# **Tratando valores nulos da coluna 'ship_region':**

# %%
cidades_nulos = orders[orders['ship_region'].isnull()]['ship_city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {cidades_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['Reims', 'Münster', 'Lyon', 'Charleroi', 'Bern', 'Genève', 'Graz', 'México D.F.', 'Köln', 'Bräcke', 'Strasbourg', 'Oulu', 'München', 'Cunewalde', 'Bergamo', 'Leipzig', 'Luleå', 'Frankfurt a.M.', 'Madrid', 'Reggio Emilia', 'London', 'Stuttgart', 'Sevilla', 'Nantes', 'Brandenburg', 'Lisboa', 'Marseille', 'Kobenhavn', 'Toulouse', 'Salzburg', 'Aachen', 'Barcelona', 'Århus', 'Warszawa', 'Stavern', 'Lille', 'Buenos Aires', 'Torino', 'Mannheim', 'Bruxelles', 'Helsinki', 'Berlin', 'Paris', 'Versailles']

# %%
cidades =['Reims', 'Münster', 'Lyon', 'Charleroi', 'Bern', 'Genève', 'Graz', 'México D.F.', 'Köln', 'Bräcke', 'Strasbourg', 'Oulu', 'München', 'Cunewalde', 'Bergamo', 'Leipzig', 'Luleå', 'Frankfurt a.M.', 'Madrid', 'Reggio Emilia', 'London', 'Stuttgart', 'Sevilla', 'Nantes', 'Brandenburg', 'Lisboa', 'Marseille', 'Kobenhavn', 'Toulouse', 'Salzburg', 'Aachen', 'Barcelona', 'Århus', 'Warszawa', 'Stavern', 'Lille', 'Buenos Aires', 'Torino', 'Mannheim', 'Bruxelles', 'Helsinki', 'Berlin', 'Paris', 'Versailles']

regioes = ['BE', 'NW', 'R', 'WBR', 'S', 'GE', 'ST', 'DF', 'NW', 'Z', 'A', 'KA', 'BY', 'SN', 'LO', 'SAC', 'BD', 'HE', 'M', 'ER', 'LDN', 'BW', 'AN', 'PDL', 'BRB', 'L', 'B', 'H', 'MP', 'S', 'NW', 'CAT', 'MJ', 'MZ', 'TE', 'NPC', 'BA', 'PI', 'BW', 'BRU', 'UUS', 'BB', 'IF', 'IF']

# %%
cidade_para_regiao = dict(zip(cidades, regioes))

orders['ship_region'] = orders.apply(lambda row: cidade_para_regiao[row['ship_city']] if pd.isnull(row['ship_region']) else row['ship_region'], axis=1)

# %% [markdown]
# > Sunstituindo os valores nulos da coluna "ship_region" com os valores da variável regioes com base nas cidades.

# %% [markdown]
# **Tratando valores nulos da coluna 'ship postal code':**

# %%
cidades_nulos = orders[orders['ship_postal_code'].isnull()]['ship_city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {cidades_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['Cork']

# %%
orders.loc[(orders['ship_city'] == 'Cork') & (orders['ship_postal_code'].isnull()), 'ship_postal_code'] = 'T12 X672'

# %% [markdown]
# > Substituindo os valores nulos da coluna "ship_postal_code" pelo 'T12 X672', encontrado com base no nome da cidade em uma pesquisa na internet.

# %% [markdown]
# **Tratando os valores nulos da coluna 'shipped_date'**:

# %% [markdown]
# fillna(pd.NaT): Isso substitui todos os valores nulos na coluna shipped_date com pd.NaT, que é reconhecido pelo pandas como um marcador para valores ausentes em datas.

# %%
orders['shipped_date'] = orders['shipped_date'].fillna(pd.NaT)

# %%
valores_nulos = orders.isnull().sum()
print(valores_nulos)
# Out:
# order_id             0
# customer_id          0
# employee_id          0
# order_date           0
# required_date        0
# shipped_date        21
# ship_via             0
# freight              0
# ship_name            0
# ship_address         0
# ship_city            0
# ship_region          0
# ship_postal_code     0
# ship_country         0
# dtype: int64

# %% [markdown]
# > Acima podemos perceber que todos os valores nulos foram tratados, apesar de "shipped_date" está com valor nulo, agora está com marcação que é recomendada nesse tipo de caso. E como estamos trabalhando com valores de data, é necessário fazer a conversão das colunas de "Object" para "datetime".

# %% [markdown]
# **Conversão das colunas de data: 'order_date', 'required_date', 'shipped_date':**

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders['required_date'] = pd.to_datetime(orders['required_date'])

# %%
orders['shipped_date'] = pd.to_datetime(orders['shipped_date'], errors='coerce')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          830 non-null    int64
#  1   customer_id       830 non-null    object
#  2   employee_id       830 non-null    int64
#  3   order_date        830 non-null    datetime64[ns]
#  4   required_date     830 non-null    datetime64[ns]
#  5   shipped_date      809 non-null    datetime64[ns]
#  6   ship_via          830 non-null    int64
#  7   freight           830 non-null    float64
#  8   ship_name         830 non-null    object
#  9   ship_address      830 non-null    object
#  10  ship_city         830 non-null    object
#  11  ship_region       830 non-null    object
#  12  ship_postal_code  830 non-null    object
#  13  ship_country      830 non-null    object
# dtypes: datetime64[ns](3), float64(1), int64(3), object(7)
# memory usage: 90.9+ KB

# %% [markdown]
# Salvando o arquivo atualizado:

# %%
orders.to_csv('./orders.csv',sep=',',index=False)

# %% [markdown]
# * **DATASET: products (produtos)**

# %% [markdown]
# **Atributos**:
#
# 1. product_id: Refere-se ao identificador único de cada produto. É usado para diferenciar e identificar unicamente cada produto no sistema.
#
# 2. product_name: Nome do produto. Ajuda na identificação e referência do produto.
#
# 3. supplier_id: Refere-se ao identificador único do fornecedor do produto. Indica qual fornecedor fornece o produto.
#
# 4. category_id: Refere-se ao identificador único da categoria do produto. Classifica o produto dentro de uma categoria específica.
#
# 5. quantity_per_unit: Descrição da quantidade do produto por unidade de venda. Especifica como o produto é embalado ou distribuído.
#
# 6. unit_price: Preço unitário do produto. Indica o custo de uma unidade do produto.
#
# 7. units_in_stock: Número de unidades do produto atualmente em estoque. Ajuda no controle de inventário e gerenciamento de estoque.
#
# 8. units_on_order: Número de unidades do produto que foram encomendadas mas ainda não foram recebidas. Auxilia no planejamento de reposição de estoque.
#
# 9. reorder_level: Nível de estoque no qual um novo pedido de reposição deve ser feito. Indica o ponto em que o produto deve ser reordenado para evitar falta de estoque.
#
# 10. discontinued: Indica se o produto foi descontinuado. Usado para identificar produtos que não são mais vendidos, onde 1 significa que o produto foi descontinuado e 0 significa que o produto ainda está ativo.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/products.csv'
products = pd.read_csv(path, sep=';')

# %%
products.head(20)
# Out:
#     product_id                     product_name  supplier_id  category_id  \
# 0            1                             Chai            8            1
# 1            2                            Chang            1            1
# 2            3                    Aniseed Syrup            1            2
# 3            4     Chef Anton's Cajun Seasoning            2            2
# 4            5           Chef Anton's Gumbo Mix            2            2
# 5            6     Grandma's Boysenberry Spread            3            2
# 6            7  Uncle Bob's Organic Dried Pears            3            7
# 7            8       Northwoods Cranberry Sauce            3            2
# 8            9                  Mishi Kobe Niku            4            6
# 9           10                            Ikura            4            8
# 10          11                   Queso Cabrales            5            4
# 11          12        Queso Manchego La Pastora            5            4
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         77 non-null     int64
#  1   product_name       77 non-null     object
#  2   supplier_id        77 non-null     int64
#  3   category_id        77 non-null     int64
#  4   quantity_per_unit  77 non-null     object
#  5   unit_price         77 non-null     float64
#  6   units_in_stock     77 non-null     int64
#  7   units_on_order     77 non-null     int64
#  8   reorder_level      77 non-null     int64
#  9   discontinued       77 non-null     int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 6.1+ KB

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = products.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Vemos que não há valores nulos, então não precisamos fazer tratamento de valores faltantes, no entanto a coluna "discontinued" possui os valores 1 e 0, representado sim para discontinuado e não para discontinuado, respectivamente, e para valores nesse formato é uma boa prática substituir pelo seu devido valor em "string".

# %% [markdown]
# **Manipulação da coluna 'discontinued':**

# %%
data = products[["discontinued"]].drop_duplicates()
data.head()
# Out:
#    discontinued
# 0             1
# 2             0

# %%
products['discontinued'] = products['discontinued'].replace([0, 1], ['No', 'Yes'])
products.head(10)
# Out:
#    product_id                     product_name  supplier_id  category_id  \
# 0           1                             Chai            8            1
# 1           2                            Chang            1            1
# 2           3                    Aniseed Syrup            1            2
# 3           4     Chef Anton's Cajun Seasoning            2            2
# 4           5           Chef Anton's Gumbo Mix            2            2
# 5           6     Grandma's Boysenberry Spread            3            2
# 6           7  Uncle Bob's Organic Dried Pears            3            7
# 7           8       Northwoods Cranberry Sauce            3            2
# 8           9                  Mishi Kobe Niku            4            6
# 9          10                            Ikura            4            8
#
#      quantity_per_unit  unit_price  units_in_stock  units_on_order  \
# 0   10 boxes x 30 bags       18.00              39               0
# ...

# %% [markdown]
# > Acima os valores 1 e 0 da coluna 'discontinued' foram substituidos por "Yes" e "No" e abaixo foi salvo o arquivo atualizado.

# %%
products.to_csv('./products.csv',sep=',',index=False)

# %% [markdown]
# * **DATASET: Region (Região)**

# %% [markdown]
# **Atributos**:
#
# 1. region_id: Refere-se ao identificador único de cada região. É usado para diferenciar e identificar unicamente cada região no sistema.
#
# 2. region_description: Descrição da região. Fornece um nome ou uma breve descrição que caracteriza a região, como Eastern, Western, Northern, ou Southern.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/region.csv'
region = pd.read_csv(path, sep=';')

# %%
region.head(20)
# Out:
#    region_id region_description
# 0          1            Eastern
# 1          2            Western
# 2          3           Northern
# 3          4           Southern

# %%
region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   region_id           4 non-null      int64
#  1   region_description  4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = region.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Vemos que não é necessário tratamento de dados.

# %% [markdown]
# * **DATASET: Shippers (Transportadora)**

# %% [markdown]
# **Atributos**:
#
# 1. shipper_id: Refere-se ao identificador único de cada transportadora. É usado para diferenciar e identificar unicamente cada transportadora no sistema.
#
# 2. company_name: Nome da empresa de transporte. Ajuda na identificação e referência da transportadora.
#
# 3. phone: Número de telefone da transportadora. Fornece um meio de contato direto com a transportadora para consultas, agendamentos ou suporte.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/shippers.csv'
shippers = pd.read_csv(path, sep=';')

# %%
shippers.head(10)
# Out:
#    shipper_id       company_name           phone
# 0           1     Speedy Express  (503) 555-9831
# 1           2     United Package  (503) 555-3199
# 2           3   Federal Shipping  (503) 555-9931
# 3           4  Alliance Shippers  1-800-222-0451
# 4           5                UPS  1-800-782-7892
# 5           6                DHL  1-800-225-5345

# %%
shippers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   shipper_id    6 non-null      int64
#  1   company_name  6 non-null      object
#  2   phone         6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 272.0+ bytes

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = shippers.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Não é necessário tratamento de valores nulos.

# %% [markdown]
# * **DATASET: suppliers (Fornecedor)**

# %% [markdown]
# **Atributos**:
#
# 1. supplier_id: Refere-se ao identificador único de cada fornecedor. É usado para diferenciar e identificar unicamente cada fornecedor no sistema.
#
# 2. company_name: Nome da empresa fornecedora. Ajuda na identificação e referência da empresa que fornece os produtos.
#
# 3. contact_name: Nome da pessoa de contato na empresa fornecedora. Facilita a comunicação direta com o representante ou responsável pelo fornecimento.
#
# 4. contact_title: Título do cargo da pessoa de contato na empresa fornecedora. Indica a posição e a responsabilidade da pessoa dentro da empresa.
#
# 5. address: Endereço da empresa fornecedora. Inclui a localização física onde a empresa está situada.
#
# 6. city: Cidade onde a empresa fornecedora está localizada. Faz parte das informações de endereço para ajudar na identificação geográfica.
#
# 7. region: Região ou estado onde a empresa fornecedora está localizada. Complementa as informações de endereço para uma localização mais precisa.
#
# 8. postal_code: Código postal da área onde a empresa fornecedora está localizada. Auxilia na entrega de correspondências e encomendas.
#
# 9. country: País onde a empresa fornecedora está localizada. Ajuda na identificação internacional da localização da empresa.
#
# 10. phone: Número de telefone da empresa fornecedora. É usado para comunicações diretas com a empresa.
#
# 11. fax: Número de fax da empresa fornecedora. É utilizado para enviar e receber documentos via fax.
#
# 12. homepage: Endereço da página inicial (site) da empresa fornecedora, se disponível. Fornece um link para informações adicionais sobre a empresa na internet.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/suppliers.csv'
suppliers = pd.read_csv(path, sep=';')

# %%
suppliers.head(10)
# Out:
#    supplier_id                        company_name  \
# 0            1                      Exotic Liquids
# 1            2          New Orleans Cajun Delights
# 2            3           Grandma Kelly's Homestead
# 3            4                       Tokyo Traders
# 4            5  Cooperativa de Quesos 'Las Cabras'
# 5            6                            Mayumi's
# 6            7                       Pavlova, Ltd.
# 7            8            Specialty Biscuits, Ltd.
# 8            9                    PB Knäckebröd AB
# 9           10           Refrescos Americanas LTDA
#
#                  contact_name             contact_title  \
# 0            Charlotte Cooper        Purchasing Manager
# 1               Shelley Burke       Order Administrator
# 2               Regina Murphy      Sales Representative
# 3                Yoshi Nagase         Marketing Manager
# 4  Antonio del Valle Saavedra      Export Administrator
# 5                 Mayumi Ohno  Marketing Representative
# ...

# %%
suppliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   supplier_id    29 non-null     int64
#  1   company_name   29 non-null     object
#  2   contact_name   29 non-null     object
#  3   contact_title  29 non-null     object
#  4   address        29 non-null     object
#  5   city           29 non-null     object
#  6   region         9 non-null      object
#  7   postal_code    29 non-null     object
#  8   country        29 non-null     object
#  9   phone          29 non-null     object
#  10  fax            13 non-null     object
#  11  homepage       5 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 2.8+ KB

# %% [markdown]
# Verificando valores nulos:

# %%
valores_nulos = suppliers.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Há valores nulos na tabela.

# %%
valores_nulos = suppliers.isnull().sum()
print(valores_nulos)
# Out:
# supplier_id       0
# company_name      0
# contact_name      0
# contact_title     0
# address           0
# city              0
# region           20
# postal_code       0
# country           0
# phone             0
# fax              16
# homepage         24
# dtype: int64

# %% [markdown]
# **Tratando valores nulos da coluna "region":**

# %%
cidades_nulos = suppliers[suppliers['region'].isnull()]['city'].unique().tolist()

print(f"Cidades onde a coluna 'region' possui valores nulos: {cidades_nulos}")
# Out:
# Cidades onde a coluna 'region' possui valores nulos: ['London', 'Tokyo', 'Osaka', 'Manchester', 'Göteborg', 'Sao Paulo', 'Berlin', 'Frankfurt', 'Cuxhaven', 'Ravenna', 'Sandvika', 'Stockholm', 'Paris', 'Singapore', 'Lyngby', 'Zaandam', 'Lappeenranta', 'Salerno', 'Montceau', 'Annecy']

# %%
cidades = ['London', 'Tokyo', 'Osaka', 'Manchester', 'Göteborg', 'Sao Paulo', 'Berlin', 'Frankfurt', 'Cuxhaven',
           'Ravenna', 'Sandvika', 'Stockholm', 'Paris', 'Singapore', 'Lyngby', 'Zaandam', 'Lappeenranta', 'Salerno',
           'Montceau', 'Annecy']
regioes = ['LDN', 'TKY', 'OSK', 'MAN', 'GOT', 'SP', 'BER', 'FF', 'CUX', 'RVN', 'SND', 'STK', 'PAR', 'SGP', 'LYN',
           'ZND', 'LAP', 'SAL', 'MTC', 'ANC']

cidade_para_regiao = dict(zip(cidades, regioes))

# %%
suppliers['region'] = suppliers.apply(lambda row: cidade_para_regiao.get(row['city'], row['region']), axis=1)

# %% [markdown]
# > Substituindo os valores nulos da coluna 'region" pelos valores de regioes com base nas cidades.

# %% [markdown]
# **Tratando os valores nulos da coluna 'fax':**

# %%
suppliers['fax'] = suppliers['fax'].fillna('desconhecido')

# %% [markdown]
# > Substituindo os valores nulos por 'desconhecido'.

# %% [markdown]
# **Tratando os valores nulo da coluna 'homepage':**

# %%
suppliers = suppliers.drop(columns=['homepage'])

# %% [markdown]
# > Remoção da coluna 'homepage' da tabela.

# %%
valores_nulos = suppliers.isnull().sum()
print(valores_nulos)
# Out:
# supplier_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %% [markdown]
# > Agora podemos observar que não temos valores nulos presente e abaixo foi salvo o arquivo atualizado.

# %%
suppliers.to_csv('./suppliers.csv',sep=',',index=False)

# %% [markdown]
# * **DATASET: territories (Território)**

# %% [markdown]
# **Atributos**:
#
# 1. territory_id: Refere-se ao identificador único de cada território. É usado para diferenciar e identificar unicamente cada território no sistema.
#
# 2. territory_description: Descrição do território. Fornece um nome ou uma breve descrição que caracteriza o território, como Westboro, Bedford, Georgetow, Boston, etc.
#
# 3. region_id: Refere-se ao identificador único da região associada ao território. Indica a qual região cada território pertence, permitindo a associação de territórios a suas respectivas regiões.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/territories.csv'
territories = pd.read_csv(path, sep=';')

# %%
territories.head(10)
# Out:
#    territory_id territory_description  region_id
# 0          1581              Westboro          1
# 1          1730               Bedford          1
# 2          1833             Georgetow          1
# 3          2116                Boston          1
# 4          2139             Cambridge          1
# 5          2184             Braintree          1
# 6          2903            Providence          1
# 7          3049                Hollis          3
# 8          3801            Portsmouth          3
# 9          6897                Wilton          1

# %%
territories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   territory_id           53 non-null     int64
#  1   territory_description  53 non-null     object
#  2   region_id              53 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# Verificando valores nulo:

# %%
valores_nulos = territories.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Não é necessário tratamento de dados.

# %% [markdown]
# * **DATASET: us_states (Estados)**

# %% [markdown]
# **Atributos**:
#
# 1. state_id: Refere-se ao identificador único de cada estado. É usado para diferenciar e identificar unicamente cada estado no sistema.
#
# 2. state_name: Nome completo do estado. Ajuda na identificação e referência do estado.
#
# 3. state_abbr: Abreviação do estado. É uma forma mais curta e padronizada de referenciar o estado, como "AL" para Alabama, "AK" para Alaska, "AZ" para Arizona, etc.
#
# 4. state_region: Região geográfica onde o estado está localizado. Pode indicar se o estado pertence ao sul, norte, oeste, leste, etc., facilitando a categorização e análise por região.

# %% [markdown]
# Leitura:

# %%
path = '/content/drive/MyDrive/northwind/us_states.csv'
us_states = pd.read_csv(path, sep=';')

# %%
us_states.head(5)
# Out:
#    state_id  state_name state_abbr state_region
# 0         1     Alabama         AL        south
# 1         2      Alaska         AK        north
# 2         3     Arizona         AZ         west
# 3         4    Arkansas         AR        south
# 4         5  California         CA         west

# %%
us_states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state_id      51 non-null     int64
#  1   state_name    51 non-null     object
#  2   state_abbr    51 non-null     object
#  3   state_region  51 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.7+ KB

# %% [markdown]
# Verificando valores nulo:

# %%
valores_nulos = us_states.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %% [markdown]
# > Não é necessário nenhum pré-processamento nos dados.

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Neste caderno, abordamos uma etapa fundamental na análise de dados: o pré-processamento. Garantimos que os dados estão em alta qualidade antes de serem integrados ao Power BI. Este processo não só assegurou a integridade dos dados, mas também nos proporcionou um entendimento mais profundo sobre as informações com as quais estamos trabalhando. Além disso, identificamos possíveis análises e insights que podem ser gerados a partir desses dados, preparando o caminho para decisões estratégicas mais informadas e eficazes.
